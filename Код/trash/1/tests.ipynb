# %%
import numpy as np
from model import EspAlgorithm, NeatAlgorithm
from model import visualize_metric_per_epoch
import torch
import pandas as pd

dataset = pd.read_csv('diabetes.csv', header=None, sep=',', engine='python')
# delete first row
dataset = dataset.drop([0])
dataset.head()

# make all data float
dataset = dataset.astype(float)

# %%
NEAT = NeatAlgorithm(input_size=8, output_size=1, population_size=100, mutation_rate=0.1, crossover_rate=0.5, max_generations=100, dataset=dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# a:\Профиль\Rab Table\Учёба\2\Neuroevolutionary-computing\Код\180523\tests.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/a%3A/%D0%9F%D1%80%D0%BE%D1%84%D0%B8%D0%BB%D1%8C/Rab%20Table/%D0%A3%D1%87%D1%91%D0%B1%D0%B0/2/Neuroevolutionary-computing/%D0%9A%D0%BE%D0%B4/180523/tests.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> NEAT = NeatAlgorithm(input_size=8, output_size=1, population_size=100, mutation_rate=0.1, crossover_rate=0.5, max_generations=100, dataset=dataset)
#
# TypeError: NeatAlgorithm.__init__() got an unexpected keyword argument 'dataset'

# %%
ESP = EspAlgorithm(50, 20,  b=5, x=dataset.iloc[:, :-1], y=dataset.iloc[:, -1])
history = ESP.run_alg(0.4)
# Out:
# 50 13.58267836526263
# 50 13.58267836526263
# 50 12.897945980143936
# 50 12.897945980143936
# 50 12.897945980143936
# 50 12.637760901204322
# 50 12.420971245569012
# 50 12.420971245569012
# 50 12.420971245569012
# 50 12.420971245569012
# 50 12.420971245569012
# 50 12.420971245569012
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 50 1.5959489712678991
# 49 1.5532617409955958
# 49 1.5532617409955958
# 49 1.5532617409955958
# 48 1.5492671219001053
# 48 1.5492671219001053
# 48 1.5492671219001053
# 47 1.4918155446834938
# 47 1.4918155446834938
# 47 1.4918155446834938
# 46 1.4905354631099603
# 46 1.4905354631099603
# 46 1.4905354631099603
# 45 1.4447124568991168
# 45 1.4447124568991168
# 45 1.4447124568991168
# 44 1.390930050136839
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 44 1.3010192634428372
# 43 1.1733306654188878
# 43 1.1733306654188878
# 43 1.1733306654188878
# 42 1.1543914964342739
# 42 1.1543914964342739
# 42 1.1543914964342739
# 41 1.1132787723970037
# 41 1.1132787723970037
# 41 1.1132787723970037
# 40 1.1111841090622974
# 40 1.1111841090622974
# 40 1.1111841090622974
# 41 0.9162980882619483
# 41 0.9162980882619483
# 41 0.9162980882619483
# 41 0.8534277196454081
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 41 0.8102416409261869
# 40 0.7072835409214067
# 40 0.7072835409214067
# 40 0.7072835409214067
# 39 0.6777463068686304
# 39 0.6777463068686304
# 39 0.6777463068686304
# 38 0.6733852060522256
# 38 0.6733852060522256
# 38 0.6733852060522256
# 37 0.6508331835243437
# 37 0.6508331835243437
# 37 0.6508331835243437
# 36 0.6506111725762843
# 36 0.6506111725762843
# 36 0.6506111725762843
# 35 0.6490943607167899
# 35 0.6490943607167899
# 35 0.6490943607167899
# 34 0.6461967027323882
# 34 0.6461967027323882
# 34 0.6461967027323882
# 33 0.6458433912486613
# 33 0.6458433912486613
# 33 0.6458433912486613
# 32 0.6452505858722046
# 32 0.6452505858722046
# 32 0.6452505858722046

# %%
visualize_metric_per_epoch(history['loss'], 'loss')

# %%
visualize_metric_per_epoch(history['accuracy'], 'accuracy')

# %%
visualize_metric_per_epoch(history['models_hidden_size'], 'hidden')

# %%
max(history['accuracy'])
# Out:
# 0.6575520833333334

# %%
history['loss'][np.argmax(history['accuracy'])]
# Out:
# 1.3010192634428372

# %%
dataset = pd.read_csv('pima-indians-diabetes.data', header=None)
dataset.columns = ['times_pregnant',
                   'Plasma glucose concentration',
                   'Diastolic blood pressure',
                   'Triceps skin fold thickness',
                   '2-Hour serum insulin',
                   'Body mass index',
                   'Diabetes pedigree function',
                   'Age',
                   'class']
dataset
# Out:
#      times_pregnant  Plasma glucose concentration  Diastolic blood pressure  \
# 0                 6                           148                        72
# 1                 1                            85                        66
# 2                 8                           183                        64
# 3                 1                            89                        66
# 4                 0                           137                        40
# ..              ...                           ...                       ...
# 763              10                           101                        76
# 764               2                           122                        70
# 765               5                           121                        72
# 766               1                           126                        60
# 767               1                            93                        70
#
#      Triceps skin fold thickness  2-Hour serum insulin  Body mass index  \
# 0                             35                     0             33.6
# 1                             29                     0             26.6
# 2                              0                     0             23.3
# 3                             23                    94             28.1
# 4                             35                   168             43.1
# ..                           ...                   ...              ...
# 763                           48                   180             32.9
# 764                           27                     0             36.8
# 765                           23                   112             26.2
# 766                            0                     0             30.1
# 767                           31                     0             30.4
#
#      Diabetes pedigree function  Age  class
# 0                         0.627   50      1
# 1                         0.351   31      0
# 2                         0.672   32      1
# 3                         0.167   21      0
# 4                         2.288   33      1
# ..                          ...  ...    ...
# 763                       0.171   63      0
# 764                       0.340   27      0
# 765                       0.245   30      0
# 766                       0.349   47      1
# 767                       0.315   23      0
#
# [768 rows x 9 columns]

# %%
max(history['accuracy']), history['loss'][np.argmax(history['accuracy'])], history['models_hidden_size'][np.argmax(history['accuracy'])]
# Out:
# (0.6575520833333334, 1.3010192634428372, 44)

# %%
a = np.random.rand(5, 3, 7)

# %%
a[-0]
# Out:
# array([[0.71358479, 0.65709239, 0.63030465, 0.4378805 , 0.1487672 ,
#         0.2589945 , 0.10292648],
#        [0.47587562, 0.12247537, 0.79829322, 0.70443948, 0.04945979,
#         0.64201842, 0.21246546],
#        [0.92149232, 0.91452693, 0.48635031, 0.40905271, 0.61905997,
#         0.24963216, 0.3977828 ]])

# %%
np.insert(a,
          [0],
          np.random.rand(5, 3, 1), axis=2)
# Out:
# array([[[0.07303053, 0.71358479, 0.65709239, 0.63030465, 0.4378805 ,
#          0.1487672 , 0.2589945 , 0.10292648],
#         [0.55717682, 0.47587562, 0.12247537, 0.79829322, 0.70443948,
#          0.04945979, 0.64201842, 0.21246546],
#         [0.37347637, 0.92149232, 0.91452693, 0.48635031, 0.40905271,
#          0.61905997, 0.24963216, 0.3977828 ]],
#
#        [[0.92748248, 0.70628381, 0.84757332, 0.89169279, 0.79502167,
#          0.07134502, 0.1235068 , 0.16638123],
#         [0.69043282, 0.97532471, 0.12733676, 0.3262079 , 0.86097664,
#          0.6826056 , 0.5964985 , 0.70301803],
#         [0.95809319, 0.49978454, 0.19828055, 0.88732395, 0.44685643,
#          0.93125821, 0.05251964, 0.95819668]],
#
#        [[0.74900402, 0.58145504, 0.79237679, 0.55038158, 0.2862372 ,
#          0.06018489, 0.54792099, 0.16903939],
#         [0.33479326, 0.97961069, 0.70904869, 0.3566533 , 0.91663718,
#          0.4192876 , 0.75112738, 0.24772468],
#         [0.04435008, 0.73988773, 0.75146384, 0.5863785 , 0.6453715 ,
#          0.99825305, 0.80432915, 0.55585576]],
#
#        [[0.37007461, 0.71776318, 0.95208782, 0.17330133, 0.1054159 ,
#          0.48872184, 0.5037323 , 0.23689433],
#         [0.88851104, 0.34333414, 0.34015116, 0.16722774, 0.61616942,
#          0.23348789, 0.81344519, 0.62350099],
#         [0.73643533, 0.61861527, 0.55185596, 0.10466049, 0.4573355 ,
#          0.24844548, 0.22386262, 0.54185076]],
#
#        [[0.67580858, 0.65530341, 0.47075289, 0.76297497, 0.6869598 ,
#          0.07270069, 0.64608911, 0.66738694],
#         [0.89986511, 0.01988923, 0.21958867, 0.51335556, 0.19973221,
#          0.10099289, 0.95056978, 0.2816606 ],
#         [0.37242693, 0.21641032, 0.24170877, 0.18716669, 0.55728533,
#          0.38551786, 0.38944558, 0.97569437]]])

# %%
a = np.random.rand(4, 7)
a
# Out:
# array([[0.98665609, 0.31330445, 0.97736223, 0.16191328, 0.30624797,
#         0.47815152, 0.37046413],
#        [0.67291955, 0.11715987, 0.92863382, 0.06553406, 0.40064145,
#         0.16770589, 0.09191279],
#        [0.91737594, 0.42242755, 0.09414085, 0.61654966, 0.435255  ,
#         0.28445043, 0.19176846],
#        [0.20301794, 0.22852323, 0.56527378, 0.59039189, 0.2804412 ,
#         0.61287887, 0.63352496]])

# %%
np.append(a, np.array([[1,2,3,4,5,6,7]]), axis=0)
# Out:
# array([[0.98665609, 0.31330445, 0.97736223, 0.16191328, 0.30624797,
#         0.47815152, 0.37046413],
#        [0.67291955, 0.11715987, 0.92863382, 0.06553406, 0.40064145,
#         0.16770589, 0.09191279],
#        [0.91737594, 0.42242755, 0.09414085, 0.61654966, 0.435255  ,
#         0.28445043, 0.19176846],
#        [0.20301794, 0.22852323, 0.56527378, 0.59039189, 0.2804412 ,
#         0.61287887, 0.63352496],
#        [1.        , 2.        , 3.        , 4.        , 5.        ,
#         6.        , 7.        ]])
